# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 9.2: CNN with Keras
# INSTRUCTIONS:
# - Read the guides and hints, then create the necessary analysis and code to find an answer and conclusion for the task below.
# - A guide you are encouraged to read through is TensorFlow's own tutorial for immage classification, which can be found [here](https://www.tensorflow.org/tutorials/images/cnn)

# %% [markdown]
# ## CIFAR10 small image classification
# - [CIFAR10](https://www.cs.toronto.edu/~kriz/cifar.html) dataset of color training images, labeled over 10 categories.
#
# It has the classes:
# - airplane
# - automobile
# - bird
# - cat
# - deer
# - dog
# - frog
# - horse
# - ship
# - truck

# %% [markdown]
# ## Import libraries

# %%
# Uncomment the statements below if there are problems with TensorFlow on macOS
import os
# os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
# from __future__ import print_function
# import keras
# from keras.datasets import cifar10
# from keras.preprocessing.image import ImageDataGenerator
# from keras.models import Sequential
# from keras.layers import Dense, Dropout, Activation, Flatten
# from keras.layers import Conv2D, MaxPooling2D
import os

import numpy as np

import seaborn as sns
# import matplotlib
# import matplotlib.pyplot as plt

from sklearn.metrics import classification_report
import itertools

# %matplotlib inline

# %%
# insert code here
from tensorflow import keras
import tensorflow as tf

print("Keras version: ", keras.__version__)
print("Tensorflow version: ", tf.__version__)
# Out:
# Keras version:  2.5.0
# Tensorflow version:  2.5.0

# %%
# Import libraries
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix

from tensorflow.keras import datasets, layers, models
# import keras
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.layers import Conv2D
# from keras.layers import Flatten
# from keras.utils import to_categorical

# %%
# Uncomment the statement below to allow online monitoring with TensorBoard (need to be installed)
# from keras.callbacks import TensorBoard #THIS WILL BE IMPORTED INDIVIDUALLY

# %% [markdown]
# ## Load data
# Use the **Keras**' load method.

# %%
# insert code here

(train_images, train_labels), (test_images, test_labels)=datasets.cifar10.load_data()

# %%
batch_size = 32  # The default batch size of keras.
num_classes = 10  # Number of class for the dataset
epochs = 100
data_augmentation = False

# %%
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
print('x_train shape:', x_train.shape)
print('y_train shape:', y_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 1)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## Check some data

# %%
# insert code here
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(15,5)) 
# Count plot for training set
sns.countplot(y_train.ravel(), ax=axs[0])
axs[0].set_title('Distribution of training data')
axs[0].set_xlabel('Classes')
# Count plot for testing set
sns.countplot(y_test.ravel(), ax=axs[1])
axs[1].set_title('Distribution of Testing data')
axs[1].set_xlabel('Classes')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Prepare data

# %%
# insert code here

# %%
# Normalize the data. Before we need to connvert data type to float for computation.
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices. This is called one hot encoding.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ## Create the model's architecture
# - **NOTE ALERT**: Take into account the volume of data and parameters. Time and processing escalate quite fast.
# - **NOTE ALERT**: It is likely this data will require more complex models.

# %%
#define the convnet
model = models.Sequential()
# CONV => RELU => CONV => RELU => POOL => DROPOUT
model.add(layers.Conv2D(32, (3, 3), padding='same',input_shape=x_train.shape[1:]))
model.add(layers.Activation('relu'))
model.add(layers.Conv2D(32, (3, 3)))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.25))

# CONV => RELU => CONV => RELU => POOL => DROPOUT
model.add(layers.Conv2D(64, (3, 3), padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.Conv2D(64, (3, 3)))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.25))

# FLATTERN => DENSE => RELU => DROPOUT
model.add(layers.Flatten())
model.add(layers.Dense(512))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))
# a softmax classifier
model.add(layers.Dense(num_classes))
model.add(layers.Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile the model & Fit the training data

# %%
# initiate RMSprop optimizer
opt = keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
history = None  # For recording the history of trainning process.
if not data_augmentation:
    print('Not using data augmentation.')
    history = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    history = model.fit_generator(datagen.flow(x_train, y_train,
                                    batch_size=batch_size),
                                    epochs=epochs,
                                    validation_data=(x_test, y_test),
                                    workers=4)
# Out:
# Not using data augmentation.
# Epoch 1/100
# 1563/1563 [==============================] - 102s 65ms/step - loss: 1.7716 - accuracy: 0.3612 - val_loss: 1.3207 - val_accuracy: 0.5241
# Epoch 2/100
# 1563/1563 [==============================] - 94s 60ms/step - loss: 1.3074 - accuracy: 0.5340 - val_loss: 1.0847 - val_accuracy: 0.6164
# Epoch 3/100
# 1563/1563 [==============================] - 87s 56ms/step - loss: 1.1143 - accuracy: 0.6058 - val_loss: 0.9892 - val_accuracy: 0.6490
# Epoch 4/100
# 1563/1563 [==============================] - 84s 54ms/step - loss: 1.0162 - accuracy: 0.6440 - val_loss: 0.9214 - val_accuracy: 0.6781
# Epoch 5/100
# 1563/1563 [==============================] - 86s 55ms/step - loss: 0.9564 - accuracy: 0.6630 - val_loss: 0.8659 - val_accuracy: 0.6936
# Epoch 6/100
# 1563/1563 [==============================] - 79s 51ms/step - loss: 0.9251 - accuracy: 0.6761 - val_loss: 0.8228 - val_accuracy: 0.7154
# Epoch 7/100
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.8984 - accuracy: 0.6858 - val_loss: 0.8299 - val_accuracy: 0.7072
# Epoch 8/100
# 1563/1563 [==============================] - 77s 49ms/step - loss: 0.8826 - accuracy: 0.6916 - val_loss: 0.8043 - val_accuracy: 0.7210
# Epoch 9/100
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.8630 - accuracy: 0.6998 - val_loss: 0.8303 - val_accuracy: 0.7131
# Epoch 10/100
# 1563/1563 [==============================] - 82s 53ms/step - loss: 0.8477 - accuracy: 0.7042 - val_loss: 0.8073 - val_accuracy: 0.7185
# Epoch 11/100
# 1563/1563 [==============================] - 87s 56ms/step - loss: 0.8354 - accuracy: 0.7095 - val_loss: 0.7947 - val_accuracy: 0.7216
# Epoch 12/100
# 1563/1563 [==============================] - 84s 54ms/step - loss: 0.8280 - accuracy: 0.7120 - val_loss: 0.7948 - val_accuracy: 0.7256
# Epoch 13/100
# 1563/1563 [==============================] - 82s 53ms/step - loss: 0.8216 - accuracy: 0.7129 - val_loss: 0.8151 - val_accuracy: 0.7196
# Epoch 14/100
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.8162 - accuracy: 0.7168 - val_loss: 0.7866 - val_accuracy: 0.7299
# Epoch 15/100
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.8142 - accuracy: 0.7176 - val_loss: 0.7606 - val_accuracy: 0.7369
# Epoch 16/100
# 1563/1563 [==============================] - 86s 55ms/step - loss: 0.8099 - accuracy: 0.7207 - val_loss: 0.7751 - val_accuracy: 0.7356
# Epoch 17/100
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.8082 - accuracy: 0.7202 - val_loss: 0.7879 - val_accuracy: 0.7308
# Epoch 18/100
# 1563/1563 [==============================] - 85s 54ms/step - loss: 0.8094 - accuracy: 0.7213 - val_loss: 0.7822 - val_accuracy: 0.7339
# Epoch 19/100
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.8087 - accuracy: 0.7233 - val_loss: 0.7624 - val_accuracy: 0.7398
# Epoch 20/100
# 1563/1563 [==============================] - 79s 50ms/step - loss: 0.8011 - accuracy: 0.7238 - val_loss: 0.7744 - val_accuracy: 0.7389
# Epoch 21/100
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.8074 - accuracy: 0.7214 - val_loss: 0.7630 - val_accuracy: 0.7442
# Epoch 22/100
# 1563/1563 [==============================] - 84s 54ms/step - loss: 0.8060 - accuracy: 0.7253 - val_loss: 0.7902 - val_accuracy: 0.7272
# Epoch 23/100
# 1563/1563 [==============================] - 82s 52ms/step - loss: 0.8094 - accuracy: 0.7253 - val_loss: 0.7628 - val_accuracy: 0.7483
# Epoch 24/100
# 1563/1563 [==============================] - 77s 50ms/step - loss: 0.8040 - accuracy: 0.7255 - val_loss: 0.7839 - val_accuracy: 0.7353
# Epoch 25/100
# 1563/1563 [==============================] - 82s 53ms/step - loss: 0.8032 - accuracy: 0.7272 - val_loss: 0.7600 - val_accuracy: 0.7411
# Epoch 26/100
# 1563/1563 [==============================] - 89s 57ms/step - loss: 0.8088 - accuracy: 0.7258 - val_loss: 0.7576 - val_accuracy: 0.7427
# Epoch 27/100
# 1563/1563 [==============================] - 89s 57ms/step - loss: 0.8066 - accuracy: 0.7249 - val_loss: 0.7835 - val_accuracy: 0.7380
# Epoch 28/100
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.8126 - accuracy: 0.7272 - val_loss: 0.7507 - val_accuracy: 0.7497
# Epoch 29/100
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.8073 - accuracy: 0.7281 - val_loss: 0.7729 - val_accuracy: 0.7435
# Epoch 30/100
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.8141 - accuracy: 0.7254 - val_loss: 0.7978 - val_accuracy: 0.7371
# Epoch 31/100
# 1563/1563 [==============================] - 85s 54ms/step - loss: 0.8160 - accuracy: 0.7262 - val_loss: 0.7744 - val_accuracy: 0.7395
# Epoch 32/100
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.8097 - accuracy: 0.7258 - val_loss: 0.8037 - val_accuracy: 0.7382
# Epoch 33/100
# 1563/1563 [==============================] - 88s 56ms/step - loss: 0.8111 - accuracy: 0.7267 - val_loss: 0.7632 - val_accuracy: 0.7471
# Epoch 34/100
# 1563/1563 [==============================] - 87s 56ms/step - loss: 0.8158 - accuracy: 0.7244 - val_loss: 0.7729 - val_accuracy: 0.7433
# Epoch 35/100
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.8165 - accuracy: 0.7249 - val_loss: 0.8060 - val_accuracy: 0.7315
# Epoch 36/100
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.8149 - accuracy: 0.7252 - val_loss: 0.7879 - val_accuracy: 0.7372
# Epoch 37/100
# 1563/1563 [==============================] - 84s 54ms/step - loss: 0.8181 - accuracy: 0.7251 - val_loss: 0.7615 - val_accuracy: 0.7507
# Epoch 38/100
# 1563/1563 [==============================] - 82s 53ms/step - loss: 0.8173 - accuracy: 0.7252 - val_loss: 0.7671 - val_accuracy: 0.7472
# Epoch 39/100
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.8144 - accuracy: 0.7267 - val_loss: 0.7780 - val_accuracy: 0.7411
# Epoch 40/100
# 1563/1563 [==============================] - 89s 57ms/step - loss: 0.8192 - accuracy: 0.7253 - val_loss: 0.7814 - val_accuracy: 0.7412
# Epoch 41/100
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.8175 - accuracy: 0.7260 - val_loss: 0.7624 - val_accuracy: 0.7515
# Epoch 42/100
# 1563/1563 [==============================] - 84s 54ms/step - loss: 0.8216 - accuracy: 0.7243 - val_loss: 0.7640 - val_accuracy: 0.7469
# Epoch 43/100
# 1563/1563 [==============================] - 84s 54ms/step - loss: 0.8261 - accuracy: 0.7224 - val_loss: 0.7929 - val_accuracy: 0.7412
# Epoch 44/100
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.8292 - accuracy: 0.7243 - val_loss: 0.7872 - val_accuracy: 0.7429
# Epoch 45/100
# 1563/1563 [==============================] - 84s 54ms/step - loss: 0.8262 - accuracy: 0.7229 - val_loss: 0.8015 - val_accuracy: 0.7418
# Epoch 46/100
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.8310 - accuracy: 0.7232 - val_loss: 0.7909 - val_accuracy: 0.7434
# Epoch 47/100
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.8298 - accuracy: 0.7229 - val_loss: 0.7902 - val_accuracy: 0.7371
# Epoch 48/100
# 1563/1563 [==============================] - 84s 54ms/step - loss: 0.8318 - accuracy: 0.7225 - val_loss: 0.7600 - val_accuracy: 0.7504
# Epoch 49/100
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.8321 - accuracy: 0.7237 - val_loss: 0.8351 - val_accuracy: 0.7307
# Epoch 50/100
# 1563/1563 [==============================] - 86s 55ms/step - loss: 0.8391 - accuracy: 0.7211 - val_loss: 0.7903 - val_accuracy: 0.7434
# Epoch 51/100
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.8400 - accuracy: 0.7216 - val_loss: 0.8434 - val_accuracy: 0.7215
# Epoch 52/100
# 1563/1563 [==============================] - 84s 54ms/step - loss: 0.8336 - accuracy: 0.7218 - val_loss: 0.7976 - val_accuracy: 0.7426
# Epoch 53/100
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.8382 - accuracy: 0.7223 - val_loss: 0.7965 - val_accuracy: 0.7467
# Epoch 54/100
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.8450 - accuracy: 0.7174 - val_loss: 0.8290 - val_accuracy: 0.7392
# Epoch 55/100
# 1563/1563 [==============================] - 88s 56ms/step - loss: 0.8391 - accuracy: 0.7193 - val_loss: 0.8230 - val_accuracy: 0.7293
# Epoch 56/100
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.8433 - accuracy: 0.7201 - val_loss: 0.8562 - val_accuracy: 0.7317
# Epoch 57/100
# 1563/1563 [==============================] - 87s 56ms/step - loss: 0.8488 - accuracy: 0.7190 - val_loss: 0.8648 - val_accuracy: 0.7262
# Epoch 58/100
# 1563/1563 [==============================] - 89s 57ms/step - loss: 0.8437 - accuracy: 0.7196 - val_loss: 0.9183 - val_accuracy: 0.7030
# Epoch 59/100
# 1563/1563 [==============================] - 87s 55ms/step - loss: 0.8421 - accuracy: 0.7220 - val_loss: 0.8563 - val_accuracy: 0.7239
# Epoch 60/100
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.8513 - accuracy: 0.7170 - val_loss: 0.8595 - val_accuracy: 0.7271
# Epoch 61/100
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.8451 - accuracy: 0.7192 - val_loss: 0.8120 - val_accuracy: 0.7445
# Epoch 62/100
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.8450 - accuracy: 0.7175 - val_loss: 0.8192 - val_accuracy: 0.7428
# Epoch 63/100
# 1563/1563 [==============================] - 86s 55ms/step - loss: 0.8497 - accuracy: 0.7191 - val_loss: 0.7959 - val_accuracy: 0.7347
# Epoch 64/100
# 1563/1563 [==============================] - 85s 54ms/step - loss: 0.8500 - accuracy: 0.7183 - val_loss: 0.8706 - val_accuracy: 0.7200
# Epoch 65/100
# 1563/1563 [==============================] - 86s 55ms/step - loss: 0.8545 - accuracy: 0.7167 - val_loss: 0.7844 - val_accuracy: 0.7417
# Epoch 66/100
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.8531 - accuracy: 0.7181 - val_loss: 0.8452 - val_accuracy: 0.7327
# Epoch 67/100
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.8600 - accuracy: 0.7166 - val_loss: 0.8498 - val_accuracy: 0.7325
# Epoch 68/100
# 1563/1563 [==============================] - 79s 51ms/step - loss: 0.8537 - accuracy: 0.7155 - val_loss: 0.8207 - val_accuracy: 0.7391
# Epoch 69/100
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.8610 - accuracy: 0.7150 - val_loss: 0.8286 - val_accuracy: 0.7327
# Epoch 70/100
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.8549 - accuracy: 0.7189 - val_loss: 0.8505 - val_accuracy: 0.7289
# Epoch 71/100
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.8591 - accuracy: 0.7150 - val_loss: 0.8599 - val_accuracy: 0.7191
# Epoch 72/100
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.8565 - accuracy: 0.7171 - val_loss: 0.8273 - val_accuracy: 0.7306
# Epoch 73/100
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.8612 - accuracy: 0.7186 - val_loss: 0.8143 - val_accuracy: 0.7278
# Epoch 74/100
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.8569 - accuracy: 0.7169 - val_loss: 0.8067 - val_accuracy: 0.7325
# Epoch 75/100
# 1563/1563 [==============================] - 79s 50ms/step - loss: 0.8597 - accuracy: 0.7152 - val_loss: 0.8953 - val_accuracy: 0.7239
# Epoch 76/100
# 1563/1563 [==============================] - 79s 51ms/step - loss: 0.8642 - accuracy: 0.7153 - val_loss: 0.8161 - val_accuracy: 0.7430
# Epoch 77/100
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.8657 - accuracy: 0.7151 - val_loss: 0.8469 - val_accuracy: 0.7194
# Epoch 78/100
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.8594 - accuracy: 0.7152 - val_loss: 0.9149 - val_accuracy: 0.7181
# Epoch 79/100
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.8629 - accuracy: 0.7145 - val_loss: 0.9050 - val_accuracy: 0.7329
# Epoch 80/100
# 1563/1563 [==============================] - 79s 51ms/step - loss: 0.8610 - accuracy: 0.7169 - val_loss: 0.8437 - val_accuracy: 0.7140
# Epoch 81/100
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.8686 - accuracy: 0.7127 - val_loss: 0.8781 - val_accuracy: 0.7133
# Epoch 82/100
# 1563/1563 [==============================] - 79s 50ms/step - loss: 0.8701 - accuracy: 0.7124 - val_loss: 0.9005 - val_accuracy: 0.7179
# Epoch 83/100
# 1563/1563 [==============================] - 82s 52ms/step - loss: 0.8677 - accuracy: 0.7130 - val_loss: 0.8041 - val_accuracy: 0.7340
# Epoch 84/100
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.8679 - accuracy: 0.7173 - val_loss: 0.8936 - val_accuracy: 0.7073
# Epoch 85/100
# 1563/1563 [==============================] - 86s 55ms/step - loss: 0.8741 - accuracy: 0.7096 - val_loss: 0.8057 - val_accuracy: 0.7356
# Epoch 86/100
# 1563/1563 [==============================] - 84s 54ms/step - loss: 0.8738 - accuracy: 0.7119 - val_loss: 0.8178 - val_accuracy: 0.7384
# Epoch 87/100
# 1563/1563 [==============================] - 88s 57ms/step - loss: 0.8785 - accuracy: 0.7109 - val_loss: 0.8451 - val_accuracy: 0.7399
# Epoch 88/100
# 1563/1563 [==============================] - 79s 51ms/step - loss: 0.8725 - accuracy: 0.7103 - val_loss: 0.9486 - val_accuracy: 0.7044
# Epoch 89/100
# 1563/1563 [==============================] - 88s 56ms/step - loss: 0.8716 - accuracy: 0.7101 - val_loss: 0.8866 - val_accuracy: 0.7199
# Epoch 90/100
# 1563/1563 [==============================] - 89s 57ms/step - loss: 0.8769 - accuracy: 0.7104 - val_loss: 0.8650 - val_accuracy: 0.7305
# Epoch 91/100
# 1563/1563 [==============================] - 86s 55ms/step - loss: 0.8762 - accuracy: 0.7123 - val_loss: 0.9180 - val_accuracy: 0.6984
# Epoch 92/100
# 1563/1563 [==============================] - 79s 51ms/step - loss: 0.8813 - accuracy: 0.7095 - val_loss: 0.8738 - val_accuracy: 0.7073
# Epoch 93/100
# 1563/1563 [==============================] - 82s 53ms/step - loss: 0.8835 - accuracy: 0.7065 - val_loss: 0.8788 - val_accuracy: 0.7197
# Epoch 94/100
# 1563/1563 [==============================] - 87s 56ms/step - loss: 0.8794 - accuracy: 0.7104 - val_loss: 0.9206 - val_accuracy: 0.6988
# Epoch 95/100
# 1563/1563 [==============================] - 82s 53ms/step - loss: 0.8823 - accuracy: 0.7104 - val_loss: 0.8295 - val_accuracy: 0.7285
# Epoch 96/100
# 1563/1563 [==============================] - 82s 52ms/step - loss: 0.8802 - accuracy: 0.7067 - val_loss: 0.9020 - val_accuracy: 0.7300
# Epoch 97/100
# 1563/1563 [==============================] - 79s 51ms/step - loss: 0.8862 - accuracy: 0.7076 - val_loss: 0.8461 - val_accuracy: 0.7183
# Epoch 98/100
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.8850 - accuracy: 0.7080 - val_loss: 0.8177 - val_accuracy: 0.7306
# Epoch 99/100
# 1563/1563 [==============================] - 88s 57ms/step - loss: 0.8816 - accuracy: 0.7066 - val_loss: 0.8778 - val_accuracy: 0.7203
# Epoch 100/100
# 1563/1563 [==============================] - 88s 56ms/step - loss: 0.8839 - accuracy: 0.7099 - val_loss: 0.8104 - val_accuracy: 0.7423

# %% [markdown]
# ### TensorBoard
# - TensorBoard is TensorFlow's visualisation toolkit.
# - If Tensorflow 2 and Jupyter is installed in the same environment, running the cell below will start TensorBoard within the notebook.
# - More information about how to set up TensorBoard can be found [here](https://www.tensorflow.org/tensorboard/tensorboard_in_notebooks)

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-b74b32aea9a201ca" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b74b32aea9a201ca");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Create predictions

# %%
# %%time
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

# make prediction.
pred = model.predict(x_test)
# Out:
# 313/313 [==============================] - 4s 13ms/step - loss: 0.8104 - accuracy: 0.7423
# Test loss: 0.8104230165481567
# Test accuracy: 0.7422999739646912
# CPU times: user 21.6 s, sys: 5.19 s, total: 26.8 s
# Wall time: 9.2 s

# %% [markdown]
# ## Evaluate the model

# %%
# insert code here
def plotmodelhistory(history): 
    fig, axs = plt.subplots(1,2,figsize=(15,5)) 
    # summarize history for accuracy
    axs[0].plot(history.history['accuracy']) 
    axs[0].plot(history.history['val_accuracy']) 
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy') 
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['train', 'validate'], loc='upper left')
    # summarize history for loss
    axs[1].plot(history.history['loss']) 
    axs[1].plot(history.history['val_loss']) 
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss') 
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['train', 'validate'], loc='upper left')
    plt.show()

# list all data in history
print(history.history.keys())

plotmodelhistory(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
def heatmap(data, row_labels, col_labels, ax=None, cbar_kw={}, cbarlabel="", **kwargs):
    """
    Create a heatmap from a numpy array and two lists of labels.
    """
    if not ax:
        ax = plt.gca()

    # Plot the heatmap
    im = ax.imshow(data, **kwargs)

    # Create colorbar
    cbar = ax.figure.colorbar(im, ax=ax, **cbar_kw)
    cbar.ax.set_ylabel(cbarlabel, rotation=-90, va="bottom")

    # Let the horizontal axes labeling appear on top.
    ax.tick_params(top=True, bottom=False,
                   labeltop=True, labelbottom=False)
    # We want to show all ticks...
    ax.set_xticks(np.arange(data.shape[1]))
    ax.set_yticks(np.arange(data.shape[0]))
    # ... and label them with the respective list entries.
    ax.set_xticklabels(col_labels)
    ax.set_yticklabels(row_labels)
    
    ax.set_xlabel('Predicted Label') 
    ax.set_ylabel('True Label')
    
    return im, cbar

def annotate_heatmap(im, data=None, fmt="d", threshold=None):
    """
    A function to annotate a heatmap.
    """
    # Change the text's color depending on the data.
    texts = []
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            text = im.axes.text(j, i, format(data[i, j], fmt), horizontalalignment="center",
                                 color="white" if data[i, j] > thresh else "black")
            texts.append(text)

    return texts

# %%
labels = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(pred, axis=1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_test, axis=1)
# Errors are difference between predicted labels and true labels
errors = (Y_pred_classes - Y_true != 0)

Y_pred_classes_errors = Y_pred_classes[errors]
Y_pred_errors = pred[errors]
Y_true_errors = Y_true[errors]
X_test_errors = x_test[errors]

cm = confusion_matrix(Y_true, Y_pred_classes) 
thresh = cm.max() / 2.

fig, ax = plt.subplots(figsize=(12,12))
im, cbar = heatmap(cm, labels, labels, ax=ax,
                   cmap=plt.cm.Blues, cbarlabel="count of predictions")
texts = annotate_heatmap(im, data=cm, threshold=thresh)

fig.tight_layout()
plt.show()

# %%
print(classification_report(Y_true, Y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78      1000
#            1       0.90      0.84      0.87      1000
#            2       0.66      0.58      0.62      1000
#            3       0.55      0.57      0.56      1000
#            4       0.62      0.80      0.70      1000
#            5       0.72      0.56      0.63      1000
#            6       0.74      0.84      0.79      1000
#            7       0.84      0.75      0.79      1000
#            8       0.84      0.86      0.85      1000
#            9       0.83      0.84      0.84      1000
#
#     accuracy                           0.74     10000
#    macro avg       0.75      0.74      0.74     10000
# weighted avg       0.75      0.74      0.74     10000

# %% [markdown]
# ## Visualisation of cost

# %%
# insert code here
R = 5
C = 5
fig, axes = plt.subplots(R, C, figsize=(12,12))
axes = axes.ravel()

for i in np.arange(0, R*C):
    axes[i].imshow(x_test[i])
    axes[i].set_title("True: %s \nPredict: %s" % (labels[Y_true[i]], labels[Y_pred_classes[i]]))
    axes[i].axis('off')
    plt.subplots_adjust(wspace=1)

# %%
def show_test(number):
    fig = plt.figure(figsize = (3,3))
    test_image = np.expand_dims(x_test[number], axis=0)
    test_result = model.predict_classes(test_image)
    plt.imshow(x_test[number])
    dict_key = test_result[0]
    plt.title("Predicted: {} \nTrue Label: {}".format(labels[dict_key],
                                                      labels[Y_true[number]]))

# %%
show_test(20)
# Out:
# /Users/winifredwetthasinghe/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %% [markdown]
# ## Save model and weights

# %%
# insert code here
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Saved trained model at /Users/winifredwetthasinghe/saved_models/keras_cifar10_trained_model.h5
# 313/313 [==============================] - 4s 12ms/step - loss: 0.8104 - accuracy: 0.7423
# Test loss: 0.8104230165481567
# Test accuracy: 0.7422999739646912

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
